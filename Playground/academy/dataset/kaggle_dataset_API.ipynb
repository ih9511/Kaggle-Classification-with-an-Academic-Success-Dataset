# %% [markdown]
# # Data Download Using Kaggle API
# https://velog.io/@heyggun/Kaggle%EC%BA%90%EA%B8%80-API-%EC%82%AC%EC%9A%A9-Data-Download%EB%8D%B0%EC%9D%B4%ED%84%B0-%EB%8B%A4%EC%9A%B4%EB%A1%9C%EB%93%9C

# %%
import os
import shutil
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Kaggle download
# After download Kaggle, get API key from "Kaggle my account".

# %%
# !pip install kaggle --upgrade

# %%
# !pip show kaggle

# %%
# !kaggle config view

# %%
# !kaggle competitions download -c playground-series-s4e6

# %%
filename = 'playground-series-s4e6.zip'
extrac_dir = 'kaggle dataset'
archive_format = 'zip'

shutil.unpack_archive(filename, extrac_dir, archive_format)

# %%
import os

os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'EDA_kaggle.ipynb',
#  'kaggle dataset',
#  'kaggle_dataset_API.ipynb',
#  'playground-series-s4e6.zip',
#  'ucimlrepo.ipynb']

# %%
os.listdir('kaggle dataset/')
# Out:
# ['sample_submission.csv', 'test.csv', 'train.csv']

# %%
import pandas as pd
import numpy as np

train = pd.read_csv('kaggle dataset/train.csv')
test = pd.read_csv('kaggle dataset/test.csv')

# %%
train.head()
# Out:
#    id  Marital status  Application mode  Application order  Course  \
# 0   0               1                 1                  1    9238
# 1   1               1                17                  1    9238
# 2   2               1                17                  2    9254
# 3   3               1                 1                  3    9500
# 4   4               1                 1                  2    9500
#
#    Daytime/evening attendance  Previous qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           1                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  ...  \
# 0                           126.0            1                       1  ...
# 1                           125.0            1                      19  ...
# ...

# %%
test.head()
# Out:
#       id  Marital status  Application mode  Application order  Course  \
# 0  76518               1                 1                  1    9500
# 1  76519               1                 1                  1    9238
# 2  76520               1                 1                  1    9238
# 3  76521               1                44                  1    9147
# 4  76522               1                39                  1    9670
#
#    Daytime/evening attendance  Previous qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                      39
# 4                           1                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  ...  \
# 0                           141.0            1                       3  ...
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76518 entries, 0 to 76517
# Data columns (total 38 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   id                                              76518 non-null  int64
#  1   Marital status                                  76518 non-null  int64
#  2   Application mode                                76518 non-null  int64
#  3   Application order                               76518 non-null  int64
#  4   Course                                          76518 non-null  int64
#  5   Daytime/evening attendance                      76518 non-null  int64
#  6   Previous qualification                          76518 non-null  int64
#  7   Previous qualification (grade)                  76518 non-null  float64
#  8   Nacionality                                     76518 non-null  int64
# ...
